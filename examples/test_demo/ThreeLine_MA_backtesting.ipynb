# %%
from vnpy_ctastrategy.backtesting import BacktestingEngine, OptimizationSetting
from Three_Lines import Tree_Line_Demo1
from datetime import datetime

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="MA888.CZCE",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2022, 11, 1),
    rate=0.3/10000,
    slippage=1,
    size=10,
    pricetick=0.2,
    capital=100000,
)
engine.add_strategy(Tree_Line_Demo1, {})

# %%
engine.load_data()
# Out:
# 2022-11-07 16:01:13.231805	开始加载历史数据
# 2022-11-07 16:01:13.232003	加载进度：# [0%]
# 2022-11-07 16:01:17.216220	加载进度：## [10%]
# 2022-11-07 16:01:20.944266	加载进度：### [20%]
# 2022-11-07 16:01:24.383650	加载进度：#### [30%]
# 2022-11-07 16:01:27.364759	加载进度：##### [40%]
# 2022-11-07 16:01:30.735420	加载进度：###### [50%]
# 2022-11-07 16:01:34.422202	加载进度：####### [60%]
# 2022-11-07 16:01:37.969355	加载进度：######## [70%]
# 2022-11-07 16:01:41.379336	加载进度：######### [80%]
# 2022-11-07 16:01:44.320536	加载进度：########## [90%]
# 2022-11-07 16:01:47.858616	历史数据加载完成，数据量：319800

# %%
engine.run_backtesting()
# Out:
# 2022-11-07 16:01:56.855372	策略初始化完成
# 2022-11-07 16:01:56.856366	开始回放历史数据
# 2022-11-07 16:01:57.435817	回放进度：= [0%]
# 2022-11-07 16:01:57.939532	回放进度：== [10%]
# 2022-11-07 16:01:58.337466	回放进度：=== [20%]
# 2022-11-07 16:01:58.742383	回放进度：==== [30%]
# 2022-11-07 16:01:59.117393	回放进度：===== [40%]
# 2022-11-07 16:01:59.484412	回放进度：====== [50%]
# 2022-11-07 16:01:59.845445	回放进度：======= [60%]
# 2022-11-07 16:02:00.303241	回放进度：======== [70%]
# 2022-11-07 16:02:00.713167	回放进度：========= [80%]
# 2022-11-07 16:02:01.085175	回放进度：========== [90%]
# 2022-11-07 16:02:01.086172	历史数据回放结束

# %%
engine.calculate_result()
# Out:
# 2022-11-07 16:02:05.154029	开始计算逐日盯市盈亏
# 2022-11-07 16:02:05.316969	逐日盯市盈亏计算完成
#             close_price  pre_close  \
# date
# 2019-01-16       3120.0        1.0
# 2019-01-17       3071.0     3120.0
# 2019-01-18       3145.0     3071.0
# 2019-01-21       3161.0     3145.0
# 2019-01-22       3073.0     3161.0
# ...                 ...        ...
# 2022-10-26       2555.0     2603.0
# 2022-10-27       2525.0     2555.0
# 2022-10-28       2535.0     2525.0
# 2022-10-31       2495.0     2535.0
# 2022-11-01       2528.0     2495.0
#
#                                                        trades  trade_count  \
# date
# 2019-01-16  [TradeData(gateway_name='BACKTESTING', extra=N...            6
# 2019-01-17  [TradeData(gateway_name='BACKTESTING', extra=N...            4
# 2019-01-18                                                 []            0
# 2019-01-21                                                 []            0
# 2019-01-22                                                 []            0
# ...                                                       ...          ...
# 2022-10-26                                                 []            0
# 2022-10-27                                                 []            0
# 2022-10-28                                                 []            0
# 2022-10-31                                                 []            0
# 2022-11-01                                                 []            0
#
#             start_pos  end_pos  turnover  commission  slippage  trading_pnl  \
# date
# 2019-01-16          0        0  186950.0      5.6085        60        -30.0
# 2019-01-17          0        0  124720.0      3.7416        40          0.0
# 2019-01-18          0        0       0.0      0.0000         0          0.0
# 2019-01-21          0        0       0.0      0.0000         0          0.0
# 2019-01-22          0        0       0.0      0.0000         0          0.0
# ...               ...      ...       ...         ...       ...          ...
# 2022-10-26          0        0       0.0      0.0000         0          0.0
# 2022-10-27          0        0       0.0      0.0000         0          0.0
# 2022-10-28          0        0       0.0      0.0000         0          0.0
# 2022-10-31          0        0       0.0      0.0000         0          0.0
# 2022-11-01          0        0       0.0      0.0000         0          0.0
#
#             holding_pnl  total_pnl  net_pnl
# date
# 2019-01-16          0.0      -30.0 -95.6085
# 2019-01-17         -0.0        0.0 -43.7416
# 2019-01-18          0.0        0.0   0.0000
# 2019-01-21          0.0        0.0   0.0000
# 2019-01-22         -0.0        0.0   0.0000
# ...                 ...        ...      ...
# 2022-10-26         -0.0        0.0   0.0000
# 2022-10-27         -0.0        0.0   0.0000
# 2022-10-28          0.0        0.0   0.0000
# 2022-10-31         -0.0        0.0   0.0000
# 2022-11-01          0.0        0.0   0.0000
#
# [919 rows x 13 columns]

# %%
engine.calculate_statistics()
# Out:
# 2022-11-07 16:02:10.924103	开始计算策略统计指标
# 2022-11-07 16:02:10.968979	------------------------------
# 2022-11-07 16:02:10.968979	首个交易日：	2019-01-16
# 2022-11-07 16:02:10.968979	最后交易日：	2022-11-01
# 2022-11-07 16:02:10.968979	总交易日：	919
# 2022-11-07 16:02:10.968979	盈利交易日：	64
# 2022-11-07 16:02:10.968979	亏损交易日：	90
# 2022-11-07 16:02:10.968979	起始资金：	100,000.00
# 2022-11-07 16:02:10.968979	结束资金：	94,398.91
# 2022-11-07 16:02:10.968979	总收益率：	-5.60%
# 2022-11-07 16:02:10.968979	年化收益：	-1.46%
# 2022-11-07 16:02:10.968979	最大回撤: 	-7,542.89
# 2022-11-07 16:02:10.968979	百分比最大回撤: -7.46%
# 2022-11-07 16:02:10.968979	最长回撤天数: 	216
# 2022-11-07 16:02:10.968979	总盈亏：	-5,601.09
# 2022-11-07 16:02:10.968979	总手续费：	251.09
# 2022-11-07 16:02:10.968979	总滑点：	3,180.00
# 2022-11-07 16:02:10.968979	总成交金额：	8,369,510.00
# 2022-11-07 16:02:10.968979	总成交笔数：	318
# 2022-11-07 16:02:10.968979	日均盈亏：	-6.09
# 2022-11-07 16:02:10.968979	日均手续费：	0.27
# 2022-11-07 16:02:10.968979	日均滑点：	3.46
# 2022-11-07 16:02:10.968979	日均成交金额：	9,107.19
# 2022-11-07 16:02:10.968979	日均成交笔数：	0.34602829162132753
# 2022-11-07 16:02:10.968979	日均收益率：	-0.01%
# 2022-11-07 16:02:10.968979	收益标准差：	0.16%
# 2022-11-07 16:02:10.968979	Sharpe Ratio：	-0.59
# 2022-11-07 16:02:10.968979	收益回撤比：	-0.75
# 2022-11-07 16:02:10.969976	策略统计指标计算完成
# {'start_date': datetime.date(2019, 1, 16),
#  'end_date': datetime.date(2022, 11, 1),
#  'total_days': 919,
#  'profit_days': 64,
#  'loss_days': 90,
#  'capital': 100000,
#  'end_balance': 94398.9147,
#  'max_drawdown': -7542.885300000009,
#  'max_ddpercent': -7.462223750493768,
#  'max_drawdown_duration': 216,
#  'total_net_pnl': -5601.0853,
#  'daily_net_pnl': -6.0947609357997825,
#  'total_commission': 251.08529999999996,
#  'daily_commission': 0.27321577801958646,
#  'total_slippage': 3180,
#  'daily_slippage': 3.4602829162132753,
#  'total_turnover': 8369510.0,
#  'daily_turnover': 9107.192600652883,
#  'total_trade_count': 318,
#  'daily_trade_count': 0.34602829162132753,
#  'total_return': -5.601085300000008,
#  'annual_return': -1.46274262459195,
#  'daily_return': -0.006272101167003248,
#  'return_std': 0.16481964340510646,
#  'sharpe_ratio': -0.5895351516038791,
#  'return_drawdown_ratio': -0.7505919799884572}

# %%
engine.show_chart()

# %%
setting = OptimizationSetting()
setting.set_target("total_net_pnl")
setting.add_parameter("donchian_in_length", 15, 30, 2)
setting.add_parameter("donchian_out_length", 6, 16, 2)

engine.run_optimization(setting)
# Out:
# 2022-11-07 09:13:51.860149	开始执行穷举算法优化
# 2022-11-07 09:13:51.861148	参数优化空间：48
# 2022-11-07 09:16:40.753944	穷举算法优化完成，耗时168秒
# 2022-11-07 09:16:44.949810	参数：{'donchian_in_length': 21, 'donchian_out_length': 16}, 目标：7335.762100000001
# 2022-11-07 09:16:44.949810	参数：{'donchian_in_length': 23, 'donchian_out_length': 16}, 目标：6850.6419000000005
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 17, 'donchian_out_length': 16}, 目标：6656.1656
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 27, 'donchian_out_length': 16}, 目标：6207.833900000001
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 19, 'donchian_out_length': 16}, 目标：6138.735000000001
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 21, 'donchian_out_length': 14}, 目标：5779.156199999999
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 29, 'donchian_out_length': 6}, 目标：4670.583399999999
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 29, 'donchian_out_length': 8}, 目标：4654.698099999999
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 21, 'donchian_out_length': 12}, 目标：4429.745
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 29, 'donchian_out_length': 16}, 目标：4419.863200000002
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 25, 'donchian_out_length': 16}, 目标：4345.7624
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 27, 'donchian_out_length': 12}, 目标：4275.477400000002
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 29, 'donchian_out_length': 12}, 目标：4199.989699999999
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 23, 'donchian_out_length': 14}, 目标：3946.6061000000036
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 27, 'donchian_out_length': 6}, 目标：3941.029900000001
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 17, 'donchian_out_length': 14}, 目标：3404.5044999999977
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 23, 'donchian_out_length': 12}, 目标：2985.3428999999996
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 19, 'donchian_out_length': 14}, 目标：2902.492800000002
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 17, 'donchian_out_length': 12}, 目标：2292.062199999998
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 27, 'donchian_out_length': 8}, 目标：1994.4699000000016
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 27, 'donchian_out_length': 14}, 目标：1920.1248000000005
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 19, 'donchian_out_length': 12}, 目标：1748.669200000002
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 15, 'donchian_out_length': 16}, 目标：834.711199999995
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 25, 'donchian_out_length': 14}, 目标：515.1486999999985
# 2022-11-07 09:16:44.950807	参数：{'donchian_in_length': 29, 'donchian_out_length': 14}, 目标：336.73870000000124
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 17, 'donchian_out_length': 8}, 目标：159.98739999999702
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 29, 'donchian_out_length': 10}, 目标：139.32099999999855
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 23, 'donchian_out_length': 8}, 目标：127.83000000000243
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 17, 'donchian_out_length': 6}, 目标：-952.7796000000008
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 21, 'donchian_out_length': 8}, 目标：-1178.7103000000016
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 27, 'donchian_out_length': 10}, 目标：-1389.4303
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 23, 'donchian_out_length': 6}, 目标：-1429.0910999999967
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 15, 'donchian_out_length': 14}, 目标：-2053.4626000000007
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 17, 'donchian_out_length': 10}, 目标：-2279.828900000003
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 25, 'donchian_out_length': 12}, 目标：-2499.840899999999
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 19, 'donchian_out_length': 8}, 目标：-2793.832700000002
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 23, 'donchian_out_length': 10}, 目标：-3038.9515000000015
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 21, 'donchian_out_length': 6}, 目标：-3103.1733999999988
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 21, 'donchian_out_length': 10}, 目标：-3598.4166
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 19, 'donchian_out_length': 6}, 目标：-4223.6274
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 19, 'donchian_out_length': 10}, 目标：-4265.667000000001
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 15, 'donchian_out_length': 12}, 目标：-4527.446200000002
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 25, 'donchian_out_length': 6}, 目标：-4708.952999999998
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 25, 'donchian_out_length': 8}, 目标：-5197.766699999999
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 15, 'donchian_out_length': 8}, 目标：-5273.501400000001
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 15, 'donchian_out_length': 6}, 目标：-6703.356400000002
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 25, 'donchian_out_length': 10}, 目标：-7928.770399999999
# 2022-11-07 09:16:44.951804	参数：{'donchian_in_length': 15, 'donchian_out_length': 10}, 目标：-9744.259000000002
# [("{'donchian_in_length': 21, 'donchian_out_length': 16}",
#   7335.762100000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 414,
#    'loss_days': 463,
#    'capital': 100000,
#    'end_balance': 107335.76209999999,
#    'max_drawdown': -10107.638100000011,
#    'max_ddpercent': -8.97912808318681,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': 7335.762100000001,
#    'daily_net_pnl': 8.251700899887515,
#    'total_commission': 744.2379,
#    'daily_commission': 0.8371629921259842,
#    'total_slippage': 9570,
#    'daily_slippage': 10.764904386951631,
#    'total_turnover': 24807930.0,
#    'daily_turnover': 27905.43307086614,
#    'total_trade_count': 957,
#    'daily_trade_count': 1.076490438695163,
#    'total_return': 7.335762099999998,
#    'annual_return': 1.980408215973003,
#    'daily_return': 0.007963070741626846,
#    'return_std': 0.4778424258340013,
#    'sharpe_ratio': 0.25816745185959006,
#    'return_drawdown_ratio': 0.8169793360823115}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 16}",
#   6850.6419000000005,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 407,
#    'loss_days': 468,
#    'capital': 100000,
#    'end_balance': 106850.64189999999,
#    'max_drawdown': -9614.27840000001,
#    'max_ddpercent': -8.574642622584486,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': 6850.6419000000005,
#    'daily_net_pnl': 7.706008886389202,
#    'total_commission': 709.3580999999999,
#    'daily_commission': 0.7979281214848143,
#    'total_slippage': 9130,
#    'daily_slippage': 10.269966254218224,
#    'total_turnover': 23645270.0,
#    'daily_turnover': 26597.604049493813,
#    'total_trade_count': 913,
#    'daily_trade_count': 1.0269966254218224,
#    'total_return': 6.8506418999999985,
#    'annual_return': 1.8494421327334079,
#    'daily_return': 0.007453521175044993,
#    'return_std': 0.476740309198531,
#    'sharpe_ratio': 0.24220618919414458,
#    'return_drawdown_ratio': 0.7989419736230527}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 16}",
#   6656.1656,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 437,
#    'loss_days': 445,
#    'capital': 100000,
#    'end_balance': 106656.1656,
#    'max_drawdown': -10899.593300000008,
#    'max_ddpercent': -9.516436396881039,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 6656.1656,
#    'daily_net_pnl': 7.487250393700788,
#    'total_commission': 833.8344,
#    'daily_commission': 0.9379464566929133,
#    'total_slippage': 10730,
#    'daily_slippage': 12.069741282339708,
#    'total_turnover': 27794480.0,
#    'daily_turnover': 31264.88188976378,
#    'total_trade_count': 1073,
#    'daily_trade_count': 1.2069741282339708,
#    'total_return': 6.656165599999997,
#    'annual_return': 1.7969400944881881,
#    'daily_return': 0.007248601663813333,
#    'return_std': 0.5139398934850608,
#    'sharpe_ratio': 0.21849802969659105,
#    'return_drawdown_ratio': 0.6994388784210779}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 16}",
#   6207.833900000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 397,
#    'loss_days': 466,
#    'capital': 100000,
#    'end_balance': 106207.8339,
#    'max_drawdown': -9384.8174,
#    'max_ddpercent': -8.840972766827557,
#    'max_drawdown_duration': 518,
#    'total_net_pnl': 6207.833900000001,
#    'daily_net_pnl': 6.982940269966256,
#    'total_commission': 652.1661,
#    'daily_commission': 0.7335951631046119,
#    'total_slippage': 8390,
#    'daily_slippage': 9.437570303712036,
#    'total_turnover': 21738870.0,
#    'daily_turnover': 24453.172103487064,
#    'total_trade_count': 839,
#    'daily_trade_count': 0.9437570303712036,
#    'total_return': 6.207833899999993,
#    'annual_return': 1.675905664791899,
#    'daily_return': 0.0067747677880685055,
#    'return_std': 0.4653483100289942,
#    'sharpe_ratio': 0.22553912630285,
#    'return_drawdown_ratio': 0.7021663864063202}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 16}",
#   6138.735000000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 433,
#    'loss_days': 446,
#    'capital': 100000,
#    'end_balance': 106138.73499999999,
#    'max_drawdown': -10682.890800000008,
#    'max_ddpercent': -9.540418577297242,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': 6138.735000000001,
#    'daily_net_pnl': 6.90521372328459,
#    'total_commission': 791.265,
#    'daily_commission': 0.8900618672665916,
#    'total_slippage': 10170,
#    'daily_slippage': 11.439820022497187,
#    'total_turnover': 26375500.0,
#    'daily_turnover': 29668.72890888639,
#    'total_trade_count': 1017,
#    'daily_trade_count': 1.1439820022497187,
#    'total_return': 6.138734999999995,
#    'annual_return': 1.6572512935883001,
#    'daily_return': 0.006701560530868174,
#    'return_std': 0.5001239037232182,
#    'sharpe_ratio': 0.20758881658268086,
#    'return_drawdown_ratio': 0.643445038628386}),
#  ("{'donchian_in_length': 21, 'donchian_out_length': 14}",
#   5779.156199999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 397,
#    'loss_days': 481,
#    'capital': 100000,
#    'end_balance': 105779.1562,
#    'max_drawdown': -12156.040500000003,
#    'max_ddpercent': -10.714865833336885,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': 5779.156199999999,
#    'daily_net_pnl': 6.5007381327334075,
#    'total_commission': 790.8437999999999,
#    'daily_commission': 0.8895880764904386,
#    'total_slippage': 10190,
#    'daily_slippage': 11.462317210348706,
#    'total_turnover': 26361460.0,
#    'daily_turnover': 29652.935883014623,
#    'total_trade_count': 1019,
#    'daily_trade_count': 1.1462317210348707,
#    'total_return': 5.779156200000002,
#    'annual_return': 1.5601771518560184,
#    'daily_return': 0.006319831573078682,
#    'return_std': 0.46474698022363437,
#    'sharpe_ratio': 0.21066604819329018,
#    'return_drawdown_ratio': 0.5393587087221813}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 6}",
#   4670.583399999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 373,
#    'loss_days': 469,
#    'capital': 100000,
#    'end_balance': 104670.5834,
#    'max_drawdown': -7734.998300000007,
#    'max_ddpercent': -7.108380394145568,
#    'max_drawdown_duration': 104,
#    'total_net_pnl': 4670.583399999999,
#    'daily_net_pnl': 5.253749606299211,
#    'total_commission': 739.4166,
#    'daily_commission': 0.8317397075365579,
#    'total_slippage': 9510,
#    'daily_slippage': 10.697412823397075,
#    'total_turnover': 24647220.0,
#    'daily_turnover': 27724.656917885266,
#    'total_trade_count': 951,
#    'daily_trade_count': 1.0697412823397074,
#    'total_return': 4.670583399999995,
#    'annual_return': 1.2608999055118095,
#    'daily_return': 0.005134750457931491,
#    'return_std': 0.4374310297606966,
#    'sharpe_ratio': 0.18185086706243914,
#    'return_drawdown_ratio': 0.6570531036643266}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 8}",
#   4654.698099999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 368,
#    'loss_days': 474,
#    'capital': 100000,
#    'end_balance': 104654.6981,
#    'max_drawdown': -7854.998900000006,
#    'max_ddpercent': -7.441954868652452,
#    'max_drawdown_duration': 104,
#    'total_net_pnl': 4654.698099999999,
#    'daily_net_pnl': 5.235880877390325,
#    'total_commission': 725.3018999999999,
#    'daily_commission': 0.8158626546681664,
#    'total_slippage': 9330,
#    'daily_slippage': 10.494938132733408,
#    'total_turnover': 24176730.0,
#    'daily_turnover': 27195.421822272216,
#    'total_trade_count': 933,
#    'daily_trade_count': 1.049493813273341,
#    'total_return': 4.654698099999988,
#    'annual_return': 1.256611410573675,
#    'daily_return': 0.005117677767222431,
#    'return_std': 0.44084799400724245,
#    'sharpe_ratio': 0.17984140595529452,
#    'return_drawdown_ratio': 0.6254671228398399}),
#  ("{'donchian_in_length': 21, 'donchian_out_length': 12}",
#   4429.745,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 382,
#    'loss_days': 493,
#    'capital': 100000,
#    'end_balance': 104429.745,
#    'max_drawdown': -9638.0769,
#    'max_ddpercent': -8.697598910892431,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': 4429.745,
#    'daily_net_pnl': 4.982840269966254,
#    'total_commission': 840.2549999999999,
#    'daily_commission': 0.9451687289088863,
#    'total_slippage': 10810,
#    'daily_slippage': 12.159730033745781,
#    'total_turnover': 28008500.0,
#    'daily_turnover': 31505.62429696288,
#    'total_trade_count': 1081,
#    'daily_trade_count': 1.2159730033745781,
#    'total_return': 4.429744999999996,
#    'annual_return': 1.1958816647919,
#    'daily_return': 0.0048756313468304975,
#    'return_std': 0.4526436475112531,
#    'sharpe_ratio': 0.1668706861333067,
#    'return_drawdown_ratio': 0.5093066540988006}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 16}",
#   4419.863200000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 391,
#    'loss_days': 472,
#    'capital': 100000,
#    'end_balance': 104419.86319999999,
#    'max_drawdown': -9744.5487,
#    'max_ddpercent': -9.34057494247401,
#    'max_drawdown_duration': 518,
#    'total_net_pnl': 4419.863200000002,
#    'daily_net_pnl': 4.971724634420699,
#    'total_commission': 630.1368,
#    'daily_commission': 0.708815298087739,
#    'total_slippage': 8110,
#    'daily_slippage': 9.122609673790777,
#    'total_turnover': 21004560.0,
#    'daily_turnover': 23627.176602924636,
#    'total_trade_count': 811,
#    'daily_trade_count': 0.9122609673790776,
#    'total_return': 4.419863199999985,
#    'annual_return': 1.1932139122609633,
#    'daily_return': 0.004864986715366149,
#    'return_std': 0.47277065154753617,
#    'sharpe_ratio': 0.15941778506307208,
#    'return_drawdown_ratio': 0.473189629891167}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 16}",
#   4345.7624,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 403,
#    'loss_days': 465,
#    'capital': 100000,
#    'end_balance': 104345.7624,
#    'max_drawdown': -10382.213700000008,
#    'max_ddpercent': -9.352241015928296,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 4345.7624,
#    'daily_net_pnl': 4.888371653543307,
#    'total_commission': 684.2375999999999,
#    'daily_commission': 0.7696710911136108,
#    'total_slippage': 8810,
#    'daily_slippage': 9.910011248593925,
#    'total_turnover': 22807920.0,
#    'daily_turnover': 25655.70303712036,
#    'total_trade_count': 881,
#    'daily_trade_count': 0.9910011248593926,
#    'total_return': 4.345762399999997,
#    'annual_return': 1.173209196850393,
#    'daily_return': 0.004785133545920232,
#    'return_std': 0.4774956382286132,
#    'sharpe_ratio': 0.15524952312845614,
#    'return_drawdown_ratio': 0.4646760485105655}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 12}",
#   4275.477400000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 372,
#    'loss_days': 478,
#    'capital': 100000,
#    'end_balance': 104275.4774,
#    'max_drawdown': -10206.027699999991,
#    'max_ddpercent': -9.6991017420733,
#    'max_drawdown_duration': 509,
#    'total_net_pnl': 4275.477400000002,
#    'daily_net_pnl': 4.80931091113611,
#    'total_commission': 714.5225999999999,
#    'daily_commission': 0.8037374578177726,
#    'total_slippage': 9210,
#    'daily_slippage': 10.359955005624297,
#    'total_turnover': 23817420.0,
#    'daily_turnover': 26791.24859392576,
#    'total_trade_count': 921,
#    'daily_trade_count': 1.0359955005624297,
#    'total_return': 4.275477400000005,
#    'annual_return': 1.1542346186726673,
#    'daily_return': 0.004709339973343781,
#    'return_std': 0.45142371684456556,
#    'sharpe_ratio': 0.16161486078649676,
#    'return_drawdown_ratio': 0.44081168686514577}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 12}",
#   4199.989699999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 371,
#    'loss_days': 480,
#    'capital': 100000,
#    'end_balance': 104199.9897,
#    'max_drawdown': -9626.829899999997,
#    'max_ddpercent': -9.31179447068913,
#    'max_drawdown_duration': 842,
#    'total_net_pnl': 4199.989699999999,
#    'daily_net_pnl': 4.7243978627671535,
#    'total_commission': 680.0102999999999,
#    'daily_commission': 0.7649159730033744,
#    'total_slippage': 8770,
#    'daily_slippage': 9.86501687289089,
#    'total_turnover': 22667010.0,
#    'daily_turnover': 25497.199100112484,
#    'total_trade_count': 877,
#    'daily_trade_count': 0.9865016872890888,
#    'total_return': 4.199989699999995,
#    'annual_return': 1.1338554870641155,
#    'daily_return': 0.0046278790194378425,
#    'return_std': 0.4568889893366321,
#    'sharpe_ratio': 0.1569195037645299,
#    'return_drawdown_ratio': 0.45103977683575}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 14}",
#   3946.6061000000036,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 386,
#    'loss_days': 488,
#    'capital': 100000,
#    'end_balance': 103946.6061,
#    'max_drawdown': -12035.759300000005,
#    'max_ddpercent': -10.719493246894588,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 3946.6061000000036,
#    'daily_net_pnl': 4.439376940382457,
#    'total_commission': 753.3938999999999,
#    'daily_commission': 0.8474622047244094,
#    'total_slippage': 9710,
#    'daily_slippage': 10.92238470191226,
#    'total_turnover': 25113130.0,
#    'daily_turnover': 28248.740157480315,
#    'total_trade_count': 971,
#    'daily_trade_count': 1.092238470191226,
#    'total_return': 3.946606099999994,
#    'annual_return': 1.065450465691787,
#    'daily_return': 0.0043540133219660635,
#    'return_std': 0.4687555415170689,
#    'sharpe_ratio': 0.14389607880102903,
#    'return_drawdown_ratio': 0.368170958188095}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 6}",
#   3941.029900000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 376,
#    'loss_days': 464,
#    'capital': 100000,
#    'end_balance': 103941.0299,
#    'max_drawdown': -9012.381000000008,
#    'max_ddpercent': -8.520172532779794,
#    'max_drawdown_duration': 509,
#    'total_net_pnl': 3941.029900000001,
#    'daily_net_pnl': 4.4331044994375715,
#    'total_commission': 778.9700999999999,
#    'daily_commission': 0.8762318335208098,
#    'total_slippage': 10010,
#    'daily_slippage': 11.259842519685039,
#    'total_turnover': 25965670.0,
#    'daily_turnover': 29207.727784026996,
#    'total_trade_count': 1001,
#    'daily_trade_count': 1.125984251968504,
#    'total_return': 3.9410299000000037,
#    'annual_return': 1.063945079865018,
#    'daily_return': 0.004347978868867,
#    'return_std': 0.42799693020680385,
#    'sharpe_ratio': 0.15738103299616565,
#    'return_drawdown_ratio': 0.4625528279899987}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 14}",
#   3404.5044999999977,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 413,
#    'loss_days': 469,
#    'capital': 100000,
#    'end_balance': 103404.5045,
#    'max_drawdown': -14664.676399999997,
#    'max_ddpercent': -12.738839564545422,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 3404.5044999999977,
#    'daily_net_pnl': 3.829588863892011,
#    'total_commission': 895.4954999999999,
#    'daily_commission': 1.0073065241844767,
#    'total_slippage': 11550,
#    'daily_slippage': 12.992125984251969,
#    'total_turnover': 29849850.0,
#    'daily_turnover': 33576.884139482565,
#    'total_trade_count': 1155,
#    'daily_trade_count': 1.2992125984251968,
#    'total_return': 3.404504500000005,
#    'annual_return': 0.9191013273340846,
#    'daily_return': 0.0037658424035037583,
#    'return_std': 0.5061590810519595,
#    'sharpe_ratio': 0.11526056103072897,
#    'return_drawdown_ratio': 0.267253895674719}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 12}",
#   2985.3428999999996,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 373,
#    'loss_days': 498,
#    'capital': 100000,
#    'end_balance': 102985.3429,
#    'max_drawdown': -10379.657799999986,
#    'max_ddpercent': -9.39008067385584,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': 2985.3428999999996,
#    'daily_net_pnl': 3.358091001124859,
#    'total_commission': 794.6570999999999,
#    'daily_commission': 0.8938775028121484,
#    'total_slippage': 10230,
#    'daily_slippage': 11.507311586051744,
#    'total_turnover': 26488570.0,
#    'daily_turnover': 29795.91676040495,
#    'total_trade_count': 1023,
#    'daily_trade_count': 1.1507311586051743,
#    'total_return': 2.98534290000001,
#    'annual_return': 0.8059418402699688,
#    'daily_return': 0.003308941526874583,
#    'return_std': 0.45581547065763783,
#    'sharpe_ratio': 0.11246196105340253,
#    'return_drawdown_ratio': 0.31792515993093606}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 14}",
#   2902.492800000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 411,
#    'loss_days': 468,
#    'capital': 100000,
#    'end_balance': 102902.49279999999,
#    'max_drawdown': -14821.086599999995,
#    'max_ddpercent': -13.095850827946066,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 2902.492800000002,
#    'daily_net_pnl': 3.2648962879640067,
#    'total_commission': 847.5071999999999,
#    'daily_commission': 0.9533264341957254,
#    'total_slippage': 10910,
#    'daily_slippage': 12.272215973003375,
#    'total_turnover': 28250240.0,
#    'daily_turnover': 31777.547806524184,
#    'total_trade_count': 1091,
#    'daily_trade_count': 1.2272215973003375,
#    'total_return': 2.9024927999999894,
#    'annual_return': 0.7835751091113583,
#    'daily_return': 0.0032184119257702205,
#    'return_std': 0.49002601048489125,
#    'sharpe_ratio': 0.10174852373578426,
#    'return_drawdown_ratio': 0.22163453433710287}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 12}",
#   2292.062199999998,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 397,
#    'loss_days': 482,
#    'capital': 100000,
#    'end_balance': 102292.0622,
#    'max_drawdown': -12610.217699999994,
#    'max_ddpercent': -11.268094351631373,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': 2292.062199999998,
#    'daily_net_pnl': 2.578247694038243,
#    'total_commission': 957.9377999999999,
#    'daily_commission': 1.0775453318335206,
#    'total_slippage': 12350,
#    'daily_slippage': 13.89201349831271,
#    'total_turnover': 31931260.0,
#    'daily_turnover': 35918.17772778403,
#    'total_trade_count': 1235,
#    'daily_trade_count': 1.3892013498312712,
#    'total_return': 2.2920622,
#    'annual_return': 0.6187794465691789,
#    'daily_return': 0.0025491440501784817,
#    'return_std': 0.4918677539547064,
#    'sharpe_ratio': 0.08028818619676475,
#    'return_drawdown_ratio': 0.20341169753057312}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 8}",
#   1994.4699000000016,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 366,
#    'loss_days': 475,
#    'capital': 100000,
#    'end_balance': 101994.4699,
#    'max_drawdown': -10350.945800000001,
#    'max_ddpercent': -9.75993754482278,
#    'max_drawdown_duration': 509,
#    'total_net_pnl': 1994.4699000000016,
#    'daily_net_pnl': 2.2434982002249737,
#    'total_commission': 765.5301,
#    'daily_commission': 0.8611137232845893,
#    'total_slippage': 9850,
#    'daily_slippage': 11.07986501687289,
#    'total_turnover': 25517670.0,
#    'daily_turnover': 28703.790776152982,
#    'total_trade_count': 985,
#    'daily_trade_count': 1.1079865016872892,
#    'total_return': 1.9944699000000066,
#    'annual_return': 0.5384395680539951,
#    'daily_return': 0.002221418353176096,
#    'return_std': 0.4395041020121077,
#    'sharpe_ratio': 0.07830203401900002,
#    'return_drawdown_ratio': 0.20435273185308298}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 14}",
#   1920.1248000000005,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 379,
#    'loss_days': 477,
#    'capital': 100000,
#    'end_balance': 101920.1248,
#    'max_drawdown': -11062.286600000007,
#    'max_ddpercent': -10.044488248489303,
#    'max_drawdown_duration': 292,
#    'total_net_pnl': 1920.1248000000005,
#    'daily_net_pnl': 2.159870416197976,
#    'total_commission': 689.8752,
#    'daily_commission': 0.7760125984251968,
#    'total_slippage': 8890,
#    'daily_slippage': 10.0,
#    'total_turnover': 22995840.0,
#    'daily_turnover': 25867.08661417323,
#    'total_trade_count': 889,
#    'daily_trade_count': 1.0,
#    'total_return': 1.9201248000000115,
#    'annual_return': 0.5183688998875172,
#    'daily_return': 0.0021393959870425125,
#    'return_std': 0.4628959126493717,
#    'sharpe_ratio': 0.07160007079202606,
#    'return_drawdown_ratio': 0.19116203359477268}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 12}",
#   1748.669200000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 395,
#    'loss_days': 482,
#    'capital': 100000,
#    'end_balance': 101748.6692,
#    'max_drawdown': -12384.998300000007,
#    'max_ddpercent': -11.236378497565983,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': 1748.669200000002,
#    'daily_net_pnl': 1.9670069741282363,
#    'total_commission': 901.3308,
#    'daily_commission': 1.0138704161979752,
#    'total_slippage': 11590,
#    'daily_slippage': 13.037120359955006,
#    'total_turnover': 30044360.0,
#    'daily_turnover': 33795.68053993251,
#    'total_trade_count': 1159,
#    'daily_trade_count': 1.3037120359955006,
#    'total_return': 1.7486692000000081,
#    'annual_return': 0.47208167379077837,
#    'daily_return': 0.0019500066516985827,
#    'return_std': 0.4793953596172561,
#    'sharpe_ratio': 0.06301557272520955,
#    'return_drawdown_ratio': 0.1556256938460024}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 16}",
#   834.711199999995,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 430,
#    'loss_days': 453,
#    'capital': 100000,
#    'end_balance': 100834.71119999999,
#    'max_drawdown': -14221.251599999989,
#    'max_ddpercent': -12.746147827303908,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 834.711199999995,
#    'daily_net_pnl': 0.9389327334083183,
#    'total_commission': 895.2888,
#    'daily_commission': 1.0070740157480316,
#    'total_slippage': 11530,
#    'daily_slippage': 12.96962879640045,
#    'total_turnover': 29842960.0,
#    'daily_turnover': 33569.13385826772,
#    'total_trade_count': 1153,
#    'daily_trade_count': 1.296962879640045,
#    'total_return': 0.8347111999999823,
#    'annual_return': 0.22534385601799298,
#    'daily_return': 0.0009350357159418448,
#    'return_std': 0.5352396092257226,
#    'sharpe_ratio': 0.02706360062694596,
#    'return_drawdown_ratio': 0.06548733086336268}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 14}",
#   515.1486999999985,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 384,
#    'loss_days': 482,
#    'capital': 100000,
#    'end_balance': 100515.1487,
#    'max_drawdown': -12982.458999999988,
#    'max_ddpercent': -11.7723390537101,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': 515.1486999999985,
#    'daily_net_pnl': 0.5794698537682773,
#    'total_commission': 724.8512999999999,
#    'daily_commission': 0.8153557930258717,
#    'total_slippage': 9350,
#    'daily_slippage': 10.517435320584926,
#    'total_turnover': 24161710.0,
#    'daily_turnover': 27178.526434195726,
#    'total_trade_count': 935,
#    'daily_trade_count': 1.0517435320584927,
#    'total_return': 0.515148700000001,
#    'annual_return': 0.13907276490438722,
#    'daily_return': 0.0005779823942907052,
#    'return_std': 0.4734992666499311,
#    'sharpe_ratio': 0.01891040890793165,
#    'return_drawdown_ratio': 0.043759247643963314}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 14}",
#   336.73870000000124,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 376,
#    'loss_days': 481,
#    'capital': 100000,
#    'end_balance': 100336.7387,
#    'max_drawdown': -10653.931000000011,
#    'max_ddpercent': -9.908976329606043,
#    'max_drawdown_duration': 292,
#    'total_net_pnl': 336.73870000000124,
#    'daily_net_pnl': 0.37878368953880903,
#    'total_commission': 663.2612999999999,
#    'daily_commission': 0.7460757030371202,
#    'total_slippage': 8550,
#    'daily_slippage': 9.617547806524184,
#    'total_turnover': 22108710.0,
#    'daily_turnover': 24869.190101237346,
#    'total_trade_count': 855,
#    'daily_trade_count': 0.9617547806524185,
#    'total_return': 0.3367386999999944,
#    'annual_return': 0.09090808548931231,
#    'daily_return': 0.0003781473620098458,
#    'return_std': 0.47180206344301506,
#    'sharpe_ratio': 0.012416719204563558,
#    'return_drawdown_ratio': 0.03398319753715491}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 8}",
#   159.98739999999702,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 378,
#    'loss_days': 497,
#    'capital': 100000,
#    'end_balance': 100159.9874,
#    'max_drawdown': -9592.705399999992,
#    'max_ddpercent': -8.952549571679349,
#    'max_drawdown_duration': 162,
#    'total_net_pnl': 159.98739999999702,
#    'daily_net_pnl': 0.17996332958379868,
#    'total_commission': 1080.0126,
#    'daily_commission': 1.2148623172103488,
#    'total_slippage': 13900,
#    'daily_slippage': 15.635545556805399,
#    'total_turnover': 36000420.0,
#    'daily_turnover': 40495.41057367829,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.56355455568054,
#    'total_return': 0.15998740000000566,
#    'annual_return': 0.043191199100114014,
#    'daily_return': 0.00017981952361847744,
#    'return_std': 0.4511945318402966,
#    'sharpe_ratio': 0.006174170750312403,
#    'return_drawdown_ratio': 0.017870596383639425}),
#  ("{'donchian_in_length': 29, 'donchian_out_length': 10}",
#   139.32099999999855,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 364,
#    'loss_days': 485,
#    'capital': 100000,
#    'end_balance': 100139.321,
#    'max_drawdown': -9584.586200000005,
#    'max_ddpercent': -9.243637086388748,
#    'max_drawdown_duration': 518,
#    'total_net_pnl': 139.32099999999855,
#    'daily_net_pnl': 0.15671653543306924,
#    'total_commission': 710.6789999999999,
#    'daily_commission': 0.7994139482564678,
#    'total_slippage': 9150,
#    'daily_slippage': 10.29246344206974,
#    'total_turnover': 23689300.0,
#    'daily_turnover': 26647.13160854893,
#    'total_trade_count': 915,
#    'daily_trade_count': 1.0292463442069741,
#    'total_return': 0.13932100000000336,
#    'annual_return': 0.037611968503937915,
#    'daily_return': 0.00015660746720246754,
#    'return_std': 0.4434917390282396,
#    'sharpe_ratio': 0.0054705696543155624,
#    'return_drawdown_ratio': 0.015072097562674054}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 8}",
#   127.83000000000243,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 356,
#    'loss_days': 503,
#    'capital': 100000,
#    'end_balance': 100127.83,
#    'max_drawdown': -10516.910499999998,
#    'max_ddpercent': -9.656621792944863,
#    'max_drawdown_duration': 162,
#    'total_net_pnl': 127.83000000000243,
#    'daily_net_pnl': 0.1437907761529836,
#    'total_commission': 862.1699999999998,
#    'daily_commission': 0.9698200224971877,
#    'total_slippage': 11090,
#    'daily_slippage': 12.474690663667042,
#    'total_turnover': 28739000.0,
#    'daily_turnover': 32327.334083239595,
#    'total_trade_count': 1109,
#    'daily_trade_count': 1.247469066366704,
#    'total_return': 0.12783000000000655,
#    'annual_return': 0.03450978627671718,
#    'daily_return': 0.00014369895052403694,
#    'return_std': 0.44112673863140356,
#    'sharpe_ratio': 0.0050465645675776185,
#    'return_drawdown_ratio': 0.01323754856935572}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 6}",
#   -952.7796000000008,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 378,
#    'loss_days': 494,
#    'capital': 100000,
#    'end_balance': 99047.2204,
#    'max_drawdown': -10193.159999999989,
#    'max_ddpercent': -9.624726910686709,
#    'max_drawdown_duration': 515,
#    'total_net_pnl': -952.7796000000008,
#    'daily_net_pnl': -1.0717430821147365,
#    'total_commission': 1132.7795999999998,
#    'daily_commission': 1.2742177727784025,
#    'total_slippage': 14600,
#    'daily_slippage': 16.42294713160855,
#    'total_turnover': 37759320.0,
#    'daily_turnover': 42473.92575928009,
#    'total_trade_count': 1460,
#    'daily_trade_count': 1.642294713160855,
#    'total_return': -0.9527795999999977,
#    'annual_return': -0.257218339707536,
#    'daily_return': -0.0010768814209159863,
#    'return_std': 0.4414683865921104,
#    'sharpe_ratio': -0.03778973929475322,
#    'return_drawdown_ratio': -0.09899289702880706}),
#  ("{'donchian_in_length': 21, 'donchian_out_length': 8}",
#   -1178.7103000000016,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 366,
#    'loss_days': 500,
#    'capital': 100000,
#    'end_balance': 98821.2897,
#    'max_drawdown': -10659.674400000004,
#    'max_ddpercent': -9.819662470204914,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': -1178.7103000000016,
#    'daily_net_pnl': -1.3258833520809916,
#    'total_commission': 928.7103,
#    'daily_commission': 1.0446685039370078,
#    'total_slippage': 11940,
#    'daily_slippage': 13.43082114735658,
#    'total_turnover': 30957010.0,
#    'daily_turnover': 34822.28346456693,
#    'total_trade_count': 1194,
#    'daily_trade_count': 1.343082114735658,
#    'total_return': -1.1787103000000076,
#    'annual_return': -0.3182120044994396,
#    'daily_return': -0.0013337594661224905,
#    'return_std': 0.4379729579248596,
#    'sharpe_ratio': -0.04717759949942058,
#    'return_drawdown_ratio': -0.12003572460626649}),
#  ("{'donchian_in_length': 27, 'donchian_out_length': 10}",
#   -1389.4303,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 363,
#    'loss_days': 485,
#    'capital': 100000,
#    'end_balance': 98610.5697,
#    'max_drawdown': -11557.760699999999,
#    'max_ddpercent': -10.925904209232474,
#    'max_drawdown_duration': 509,
#    'total_net_pnl': -1389.4303,
#    'daily_net_pnl': -1.5629137232845893,
#    'total_commission': 749.4303,
#    'daily_commission': 0.8430037120359954,
#    'total_slippage': 9650,
#    'daily_slippage': 10.854893138357705,
#    'total_turnover': 24981010.0,
#    'daily_turnover': 28100.123734533183,
#    'total_trade_count': 965,
#    'daily_trade_count': 1.0854893138357706,
#    'total_return': -1.3894303000000052,
#    'annual_return': -0.3750992935883029,
#    'daily_return': -0.0015738731559064903,
#    'return_std': 0.4426671395040005,
#    'sharpe_ratio': -0.055080524194307486,
#    'return_drawdown_ratio': -0.12716844971292407}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 6}",
#   -1429.0910999999967,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 355,
#    'loss_days': 499,
#    'capital': 100000,
#    'end_balance': 98570.9089,
#    'max_drawdown': -10919.143200000006,
#    'max_ddpercent': -10.080427350600157,
#    'max_drawdown_duration': 352,
#    'total_net_pnl': -1429.0910999999967,
#    'daily_net_pnl': -1.607526546681661,
#    'total_commission': 889.0911,
#    'daily_commission': 1.0001024746906637,
#    'total_slippage': 11430,
#    'daily_slippage': 12.857142857142858,
#    'total_turnover': 29636370.0,
#    'daily_turnover': 33336.74915635546,
#    'total_trade_count': 1143,
#    'daily_trade_count': 1.2857142857142858,
#    'total_return': -1.4290911000000017,
#    'annual_return': -0.3858063712036,
#    'daily_return': -0.0016191236777257111,
#    'return_std': 0.43370818235901265,
#    'sharpe_ratio': -0.05783463899780376,
#    'return_drawdown_ratio': -0.14176890029517628}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 14}",
#   -2053.4626000000007,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 423,
#    'loss_days': 462,
#    'capital': 100000,
#    'end_balance': 97946.5374,
#    'max_drawdown': -17596.32299999999,
#    'max_ddpercent': -15.691409460047263,
#    'max_drawdown_duration': 152,
#    'total_net_pnl': -2053.4626000000007,
#    'daily_net_pnl': -2.3098566929133866,
#    'total_commission': 963.4626,
#    'daily_commission': 1.0837599550056243,
#    'total_slippage': 12430,
#    'daily_slippage': 13.982002249718786,
#    'total_turnover': 32115420.0,
#    'daily_turnover': 36125.33183352081,
#    'total_trade_count': 1243,
#    'daily_trade_count': 1.3982002249718786,
#    'total_return': -2.0534626,
#    'annual_return': -0.5543656062992126,
#    'daily_return': -0.0023339024647379353,
#    'return_std': 0.5391282763626427,
#    'sharpe_ratio': -0.06706504387851699,
#    'return_drawdown_ratio': -0.1308654015579946}),
#  ("{'donchian_in_length': 17, 'donchian_out_length': 10}",
#   -2279.828900000003,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 386,
#    'loss_days': 492,
#    'capital': 100000,
#    'end_balance': 97720.17109999999,
#    'max_drawdown': -11811.094799999992,
#    'max_ddpercent': -11.138609620402619,
#    'max_drawdown_duration': 517,
#    'total_net_pnl': -2279.828900000003,
#    'daily_net_pnl': -2.5644869516310496,
#    'total_commission': 1029.8289,
#    'daily_commission': 1.1584127109111362,
#    'total_slippage': 13260,
#    'daily_slippage': 14.915635545556805,
#    'total_turnover': 34327630.0,
#    'daily_turnover': 38613.757030371205,
#    'total_trade_count': 1326,
#    'daily_trade_count': 1.4915635545556805,
#    'total_return': -2.2798289000000027,
#    'annual_return': -0.6154768683914518,
#    'daily_return': -0.00259417195490268,
#    'return_std': 0.4765499830743176,
#    'sharpe_ratio': -0.08433268396083075,
#    'return_drawdown_ratio': -0.2046780502859203}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 12}",
#   -2499.840899999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 374,
#    'loss_days': 490,
#    'capital': 100000,
#    'end_balance': 97500.1591,
#    'max_drawdown': -12829.382700000002,
#    'max_ddpercent': -11.938382575764669,
#    'max_drawdown_duration': 292,
#    'total_net_pnl': -2499.840899999999,
#    'daily_net_pnl': -2.8119695163104597,
#    'total_commission': 759.8408999999999,
#    'daily_commission': 0.8547141732283464,
#    'total_slippage': 9790,
#    'daily_slippage': 11.012373453318336,
#    'total_turnover': 25328030.0,
#    'daily_turnover': 28490.472440944883,
#    'total_trade_count': 979,
#    'daily_trade_count': 1.1012373453318336,
#    'total_return': -2.4998408999999944,
#    'annual_return': -0.6748726839145092,
#    'daily_return': -0.002847713857227086,
#    'return_std': 0.4720945648000281,
#    'sharpe_ratio': -0.09344863649066891,
#    'return_drawdown_ratio': -0.2093952747899668}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 8}",
#   -2793.832700000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 378,
#    'loss_days': 492,
#    'capital': 100000,
#    'end_balance': 97206.1673,
#    'max_drawdown': -10932.728700000007,
#    'max_ddpercent': -10.30728757164534,
#    'max_drawdown_duration': 148,
#    'total_net_pnl': -2793.832700000002,
#    'daily_net_pnl': -3.1426689538807673,
#    'total_commission': 1003.8326999999999,
#    'daily_commission': 1.1291706411698537,
#    'total_slippage': 12900,
#    'daily_slippage': 14.51068616422947,
#    'total_turnover': 33461090.0,
#    'daily_turnover': 37639.02137232846,
#    'total_trade_count': 1290,
#    'daily_trade_count': 1.4510686164229472,
#    'total_return': -2.7938326999999985,
#    'annual_return': -0.7542405489313833,
#    'daily_return': -0.0031874046058560607,
#    'return_std': 0.4472077354053001,
#    'sharpe_ratio': -0.11041638128121728,
#    'return_drawdown_ratio': -0.27105411395386364}),
#  ("{'donchian_in_length': 23, 'donchian_out_length': 10}",
#   -3038.9515000000015,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 358,
#    'loss_days': 511,
#    'capital': 100000,
#    'end_balance': 96961.0485,
#    'max_drawdown': -10924.667199999996,
#    'max_ddpercent': -10.274910032521891,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': -3038.9515000000015,
#    'daily_net_pnl': -3.418393138357707,
#    'total_commission': 838.9514999999999,
#    'daily_commission': 0.9437024746906636,
#    'total_slippage': 10790,
#    'daily_slippage': 12.137232845894264,
#    'total_turnover': 27965050.0,
#    'daily_turnover': 31456.749156355454,
#    'total_trade_count': 1079,
#    'daily_trade_count': 1.2137232845894264,
#    'total_return': -3.038951499999998,
#    'annual_return': -0.8204143532058487,
#    'daily_return': -0.003471411697180014,
#    'return_std': 0.4478869964917653,
#    'sharpe_ratio': -0.12007242716415867,
#    'return_drawdown_ratio': -0.295764292863021}),
#  ("{'donchian_in_length': 21, 'donchian_out_length': 6}",
#   -3103.1733999999988,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 360,
#    'loss_days': 503,
#    'capital': 100000,
#    'end_balance': 96896.8266,
#    'max_drawdown': -11500.679600000003,
#    'max_ddpercent': -10.669525425825611,
#    'max_drawdown_duration': 352,
#    'total_net_pnl': -3103.1733999999988,
#    'daily_net_pnl': -3.4906337457817758,
#    'total_commission': 963.1733999999999,
#    'daily_commission': 1.0834346456692912,
#    'total_slippage': 12380,
#    'daily_slippage': 13.925759280089988,
#    'total_turnover': 32105780.0,
#    'daily_turnover': 36114.48818897638,
#    'total_trade_count': 1238,
#    'daily_trade_count': 1.3925759280089989,
#    'total_return': -3.1031734000000033,
#    'annual_return': -0.8377520989876274,
#    'daily_return': -0.0035459411533907206,
#    'return_std': 0.4305154832839633,
#    'sharpe_ratio': -0.1275993228299796,
#    'return_drawdown_ratio': -0.2908445573866636}),
#  ("{'donchian_in_length': 21, 'donchian_out_length': 10}",
#   -3598.4166,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 367,
#    'loss_days': 504,
#    'capital': 100000,
#    'end_balance': 96401.5834,
#    'max_drawdown': -11244.542100000006,
#    'max_ddpercent': -10.74272638271441,
#    'max_drawdown_duration': 509,
#    'total_net_pnl': -3598.4166,
#    'daily_net_pnl': -4.047712710911136,
#    'total_commission': 898.4165999999999,
#    'daily_commission': 1.0105923509561303,
#    'total_slippage': 11540,
#    'daily_slippage': 12.98087739032621,
#    'total_turnover': 29947220.0,
#    'daily_turnover': 33686.41169853768,
#    'total_trade_count': 1154,
#    'daily_trade_count': 1.2980877390326209,
#    'total_return': -3.5984165999999984,
#    'annual_return': -0.9714510506186722,
#    'daily_return': -0.004122335117579308,
#    'return_std': 0.44700125012362935,
#    'sharpe_ratio': -0.14286971460106596,
#    'return_drawdown_ratio': -0.3349630691320625}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 6}",
#   -4223.6274,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 378,
#    'loss_days': 490,
#    'capital': 100000,
#    'end_balance': 95776.3726,
#    'max_drawdown': -11443.003700000001,
#    'max_ddpercent': -10.825494193110487,
#    'max_drawdown_duration': 888,
#    'total_net_pnl': -4223.6274,
#    'daily_net_pnl': -4.750986951631046,
#    'total_commission': 1043.6273999999999,
#    'daily_commission': 1.1739340832395948,
#    'total_slippage': 13420,
#    'daily_slippage': 15.095613048368953,
#    'total_turnover': 34787580.0,
#    'daily_turnover': 39131.1361079865,
#    'total_trade_count': 1342,
#    'daily_trade_count': 1.5095613048368954,
#    'total_return': -4.223627399999996,
#    'annual_return': -1.14023686839145,
#    'daily_return': -0.004854236670184531,
#    'return_std': 0.4388356003081408,
#    'sharpe_ratio': -0.17136602198156048,
#    'return_drawdown_ratio': -0.39015562011829247}),
#  ("{'donchian_in_length': 19, 'donchian_out_length': 10}",
#   -4265.667000000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 382,
#    'loss_days': 493,
#    'capital': 100000,
#    'end_balance': 95734.333,
#    'max_drawdown': -12223.296100000007,
#    'max_ddpercent': -11.650431209157599,
#    'max_drawdown_duration': 709,
#    'total_net_pnl': -4265.667000000001,
#    'daily_net_pnl': -4.7982755905511825,
#    'total_commission': 965.6669999999999,
#    'daily_commission': 1.0862395950506185,
#    'total_slippage': 12400,
#    'daily_slippage': 13.948256467941507,
#    'total_turnover': 32188900.0,
#    'daily_turnover': 36207.98650168729,
#    'total_trade_count': 1240,
#    'daily_trade_count': 1.3948256467941507,
#    'total_return': -4.265667000000006,
#    'annual_return': -1.1515861417322852,
#    'daily_return': -0.004903621522620402,
#    'return_std': 0.4676062773688298,
#    'sharpe_ratio': -0.1624584220731767,
#    'return_drawdown_ratio': -0.36613812170720855}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 12}",
#   -4527.446200000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 403,
#    'loss_days': 483,
#    'capital': 100000,
#    'end_balance': 95472.5538,
#    'max_drawdown': -15664.919699999999,
#    'max_ddpercent': -14.56213090961713,
#    'max_drawdown_duration': 135,
#    'total_net_pnl': -4527.446200000002,
#    'daily_net_pnl': -5.092740382452196,
#    'total_commission': 1037.4461999999999,
#    'daily_commission': 1.1669811023622045,
#    'total_slippage': 13370,
#    'daily_slippage': 15.039370078740157,
#    'total_turnover': 34581540.0,
#    'daily_turnover': 38899.370078740154,
#    'total_trade_count': 1337,
#    'daily_trade_count': 1.5039370078740157,
#    'total_return': -4.527446200000007,
#    'annual_return': -1.2222576917885282,
#    'daily_return': -0.005211628185780961,
#    'return_std': 0.5276142447039444,
#    'sharpe_ratio': -0.15302505095540642,
#    'return_drawdown_ratio': -0.31090547311382766}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 6}",
#   -4708.952999999998,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 359,
#    'loss_days': 490,
#    'capital': 100000,
#    'end_balance': 95291.047,
#    'max_drawdown': -14617.547900000005,
#    'max_ddpercent': -13.44280981373272,
#    'max_drawdown_duration': 352,
#    'total_net_pnl': -4708.952999999998,
#    'daily_net_pnl': -5.296910011248591,
#    'total_commission': 838.953,
#    'daily_commission': 0.9437041619797525,
#    'total_slippage': 10790,
#    'daily_slippage': 12.137232845894264,
#    'total_turnover': 27965100.0,
#    'daily_turnover': 31456.805399325083,
#    'total_trade_count': 1079,
#    'daily_trade_count': 1.2137232845894264,
#    'total_return': -4.708952999999994,
#    'annual_return': -1.271258402699661,
#    'daily_return': -0.005425683371940654,
#    'return_std': 0.4479429072745473,
#    'sharpe_ratio': -0.1876451753119626,
#    'return_drawdown_ratio': -0.3502952928181344}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 8}",
#   -5197.766699999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 358,
#    'loss_days': 493,
#    'capital': 100000,
#    'end_balance': 94802.23329999999,
#    'max_drawdown': -13422.020199999999,
#    'max_ddpercent': -12.529700173342473,
#    'max_drawdown_duration': 162,
#    'total_net_pnl': -5197.766699999999,
#    'daily_net_pnl': -5.8467566929133845,
#    'total_commission': 817.7666999999999,
#    'daily_commission': 0.9198725534308211,
#    'total_slippage': 10530,
#    'daily_slippage': 11.844769403824522,
#    'total_turnover': 27258890.0,
#    'daily_turnover': 30662.41844769404,
#    'total_trade_count': 1053,
#    'daily_trade_count': 1.1844769403824522,
#    'total_return': -5.197766700000006,
#    'annual_return': -1.4032216062992142,
#    'daily_return': -0.006004186612792457,
#    'return_std': 0.46027903389235253,
#    'sharpe_ratio': -0.20208710844131345,
#    'return_drawdown_ratio': -0.41483568067003707}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 8}",
#   -5273.501400000001,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 396,
#    'loss_days': 489,
#    'capital': 100000,
#    'end_balance': 94726.49859999999,
#    'max_drawdown': -12297.215599999996,
#    'max_ddpercent': -11.643245704329539,
#    'max_drawdown_duration': 121,
#    'total_net_pnl': -5273.501400000001,
#    'daily_net_pnl': -5.931947581552307,
#    'total_commission': 1193.5014,
#    'daily_commission': 1.3425212598425198,
#    'total_slippage': 15340,
#    'daily_slippage': 17.255343082114734,
#    'total_turnover': 39783380.0,
#    'daily_turnover': 44750.708661417324,
#    'total_trade_count': 1534,
#    'daily_trade_count': 1.7255343082114736,
#    'total_return': -5.273501400000013,
#    'annual_return': -1.423667419572557,
#    'daily_return': -0.006094084215460771,
#    'return_std': 0.476809658808793,
#    'sharpe_ratio': -0.19800174967789308,
#    'return_drawdown_ratio': -0.4529236549598075}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 6}",
#   -6703.356400000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 392,
#    'loss_days': 492,
#    'capital': 100000,
#    'end_balance': 93296.6436,
#    'max_drawdown': -12218.156100000007,
#    'max_ddpercent': -11.86010165899241,
#    'max_drawdown_duration': 516,
#    'total_net_pnl': -6703.356400000002,
#    'daily_net_pnl': -7.540333408323963,
#    'total_commission': 1263.3564000000001,
#    'daily_commission': 1.4210983127109114,
#    'total_slippage': 16260,
#    'daily_slippage': 18.29021372328459,
#    'total_turnover': 42111880.0,
#    'daily_turnover': 47369.94375703037,
#    'total_trade_count': 1626,
#    'daily_trade_count': 1.829021372328459,
#    'total_return': -6.703356400000004,
#    'annual_return': -1.8096800179977512,
#    'daily_return': -0.007804955349652464,
#    'return_std': 0.4689140370868856,
#    'sharpe_ratio': -0.2578593063657458,
#    'return_drawdown_ratio': -0.5652022716784618}),
#  ("{'donchian_in_length': 25, 'donchian_out_length': 10}",
#   -7928.770399999999,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 361,
#    'loss_days': 501,
#    'capital': 100000,
#    'end_balance': 92071.22959999999,
#    'max_drawdown': -14217.719900000011,
#    'max_ddpercent': -13.514904959615471,
#    'max_drawdown_duration': 707,
#    'total_net_pnl': -7928.770399999999,
#    'daily_net_pnl': -8.918751856017996,
#    'total_commission': 798.7703999999999,
#    'daily_commission': 0.8985043869516309,
#    'total_slippage': 10290,
#    'daily_slippage': 11.5748031496063,
#    'total_turnover': 26625680.0,
#    'daily_turnover': 29950.146231721035,
#    'total_trade_count': 1029,
#    'daily_trade_count': 1.1574803149606299,
#    'total_return': -7.9287704000000065,
#    'annual_return': -2.1405004454443213,
#    'daily_return': -0.009292201768456614,
#    'return_std': 0.46557136523040177,
#    'sharpe_ratio': -0.3091989360730687,
#    'return_drawdown_ratio': -0.5866686020872763}),
#  ("{'donchian_in_length': 15, 'donchian_out_length': 10}",
#   -9744.259000000002,
#   {'start_date': datetime.date(2019, 3, 6),
#    'end_date': datetime.date(2022, 11, 1),
#    'total_days': 889,
#    'profit_days': 391,
#    'loss_days': 495,
#    'capital': 100000,
#    'end_balance': 90255.741,
#    'max_drawdown': -16200.239600000015,
#    'max_ddpercent': -15.617452059076578,
#    'max_drawdown_duration': 696,
#    'total_net_pnl': -9744.259000000002,
#    'daily_net_pnl': -10.960921259842522,
#    'total_commission': 1124.259,
#    'daily_commission': 1.2646332958380202,
#    'total_slippage': 14460,
#    'daily_slippage': 16.26546681664792,
#    'total_turnover': 37475300.0,
#    'daily_turnover': 42154.44319460067,
#    'total_trade_count': 1446,
#    'daily_trade_count': 1.626546681664792,
#    'total_return': -9.74425900000001,
#    'annual_return': -2.6306211023622077,
#    'daily_return': -0.011532393544420925,
#    'return_std': 0.5109211462648909,
#    'sharpe_ratio': -0.34968032516152997,
#    'return_drawdown_ratio': -0.6239339786759149})]
